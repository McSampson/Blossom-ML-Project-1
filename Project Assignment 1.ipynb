# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
SA_Crime_Stats = pd.read_csv('C:/Users/McSampson/Documents/Jupyter Notebook/SouthAfricaCrimeStats_v2.csv')
Province_Population = pd.read_csv('C:/Users/McSampson/Documents/Jupyter Notebook/ProvincePopulation.csv')
SA_Crime_Stats_df = pd.merge(SA_Crime_Stats, Province_Population, on = 'Province')
SA_Crime_Stats_df.head()
# Out:
#        Province            Station                            Category  \
# 0  Western Cape  Cape Town Central   All theft not mentioned elsewhere
# 1  Western Cape    Mitchells Plain   All theft not mentioned elsewhere
# 2  Western Cape  Cape Town Central  Theft out of or from motor vehicle
# 3  Western Cape    Mitchells Plain                  Drug-related crime
# 4  Western Cape          Bellville   All theft not mentioned elsewhere
#
#    2005-2006  2006-2007  2007-2008  2008-2009  2009-2010  2010-2011  \
# 0       6692       6341       5966       5187       4985       5127
# 1       5341       6093       6316       6803       6035       5761
# 2       3468       2924       2329       1856       2905       3051
# 3       3064       3683       4792       5699       6571       6260
# 4       3010       2828       2721       2911       2691       2180
#
#    2011-2012  2012-2013  2013-2014  2014-2015  2015-2016  Population    Area  \
# ...

# %%
SA = SA_Crime_Stats_df.groupby('Province')

SA

# %%
for Province, Province_SA_Crime_Stats_df in SA:
    print(Province)
    print(Province_SA_Crime_Stats_df)
# Out:
# Eastern Cape
#            Province      Station  \
# 20439  Eastern Cape  East London
# 20440  Eastern Cape     Humewood
# 20441  Eastern Cape   Mount Road
# 20442  Eastern Cape    Cambridge
# 20443  Eastern Cape       Walmer
# ...             ...          ...
# 25726  Eastern Cape      Madeira
# 25727  Eastern Cape         Joza
# 25728  Eastern Cape      Madeira
# 25729  Eastern Cape      Madeira
# 25730  Eastern Cape      Madeira
#
#                                                 Category  2005-2006  \
# 20439                  All theft not mentioned elsewhere       2892
# 20440                  All theft not mentioned elsewhere       2585
# 20441                  All theft not mentioned elsewhere       2234
# 20442                  All theft not mentioned elsewhere       1478
# 20443                   Burglary at residential premises       1467
# ...                                                  ...        ...
# ...

# %%
SA['Province'].max()
# Out:
# Province
# Eastern Cape      Eastern Cape
# Free State          Free State
# Gauteng                Gauteng
# Kwazulu/Natal    Kwazulu/Natal
# Limpopo                Limpopo
# Mpumalanga          Mpumalanga
# North West          North West
# Northern Cape    Northern Cape
# Western Cape      Western Cape
# Name: Province, dtype: object

# %%
SA['Category'].max()
# Out:
# Province
# Eastern Cape     Truck hijacking
# Free State       Truck hijacking
# Gauteng          Truck hijacking
# Kwazulu/Natal    Truck hijacking
# Limpopo          Truck hijacking
# Mpumalanga       Truck hijacking
# North West       Truck hijacking
# Northern Cape    Truck hijacking
# Western Cape     Truck hijacking
# Name: Category, dtype: object

# %%
SA['Area'].max()
# Out:
# Province
# Eastern Cape     168966
# Free State       129825
# Gauteng           18178
# Kwazulu/Natal     94361
# Limpopo          125755
# Mpumalanga        76495
# North West       104882
# Northern Cape    372889
# Western Cape     129462
# Name: Area, dtype: int64
